# %%
import pandas as pd
import requests
import numpy as np

# %%
df = pd.read_csv('StandardReportExports.csv', skiprows = 4, index_col = False)
df = df.drop(columns = ['Unnamed: 4'])

# %%
df1 = df[df.Time == '2014']
df1
# Out:
#     Time                                   Commodity               District  \
# 0   2014  3915 Waste, Parings And Scrap, Of Plastics          All Districts
# 1   2014  3915 Waste, Parings And Scrap, Of Plastics          Anchorage, AK
# 2   2014  3915 Waste, Parings And Scrap, Of Plastics          Baltimore, MD
# 3   2014  3915 Waste, Parings And Scrap, Of Plastics             Boston, MA
# 4   2014  3915 Waste, Parings And Scrap, Of Plastics            Buffalo, NY
# 5   2014  3915 Waste, Parings And Scrap, Of Plastics         Charleston, SC
# 6   2014  3915 Waste, Parings And Scrap, Of Plastics            Chicago, IL
# 7   2014  3915 Waste, Parings And Scrap, Of Plastics          Cleveland, OH
# 8   2014  3915 Waste, Parings And Scrap, Of Plastics     Columbia-Snake, OR
# 9   2014  3915 Waste, Parings And Scrap, Of Plastics  Dallas-Fort Worth, TX
# 10  2014  3915 Waste, Parings And Scrap, Of Plastics            Detroit, MI
# ...

# %%
df1['Value ($US)'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-c26325b3181d> in <module>
# ----> 1 df1['Value ($US)'].astype(int)
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ...

# %%
df1['Value ($US)'].sort_values()
# Out:
# 29      1,103,004
# 22      1,303,145
# 14      1,843,045
# 13      1,919,055
# 36     10,765,922
# 16     11,807,556
# 26     14,578,109
# 19     16,353,023
# 6       2,120,098
# 11      2,249,688
# 8       2,414,731
# 4      24,017,032
# 24        267,692
# 30      3,224,072
# 35      3,248,972
# 18      3,266,808
# 12      3,273,992
# 27      3,791,824
# 9          30,197
# 10     36,253,231
# 17    365,803,307
# 1         369,861
# 34     39,014,615
# 32      4,776,084
# 7         437,932
# 25     46,189,036
# 15     49,135,688
# 21      5,665,968
# 33     51,972,232
# 5      52,886,821
# 2       6,301,650
# 38      6,769,796
# 20         60,368
# 37         61,848
# 28        660,687
# 31     74,358,111
# 3       8,014,751
# 0     953,036,078
# 23     96,726,127
# Name: Value ($US), dtype: object
