# %%
import pandas as pd
import numpy as np
import requests
import seaborn as sns
from bs4 import BeautifulSoup
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import os
from dotenv import load_dotenv

# %%
api_key = os.getenv('nyt_api')

# %%
response = requests.get('https://api.nytimes.com/svc/movies/v2/critics/all.json?&api-key=AdAosfbrAgDSknKED1mN0EaAJPAbN5kB')
data  = response.json()
data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'num_results': 82,
#  'results': [{'display_name': 'A. O. Scott',
#    'sort_name': 'A. O. Scott',
#    'status': 'full-time',
# ...

# %%
names = []
N = data['results']
for n in N:
    name = n['display_name']
    names.append(name)
names
# Out:
# ['A. O. Scott',
#  'Manohla Dargis',
#  'Stephen Holden',
#  'Renata Adler',
#  'Mordaunt Hall',
#  'Thomas M. Pryor',
#  'Eugene Archer',
#  'Donal J. Henahan',
#  'Nora Sayre',
#  'D. J. R. Bruckner',
#  'Caryn James',
#  'Harold C. Schonberg',
#  'Tom Buckley',
#  'Stanley Kauffman',
#  'Andre Sennwald',
#  'Vincent Canby',
#  'Dave Kehr',
#  'Dana Stevens',
#  'B. R. Crisler',
#  'Hilton Kramer',
#  'Michael Stern',
#  'Bosley Crowther',
#  'Ned Martel',
#  'Theodore Strauss',
#  'Richard Eder',
#  'Janet Maslin',
#  'Howard Thompson',
#  'Anita Gates',
#  'John T. McManus',
#  'Lawrence Van Gelder',
#  'Walter Goodman',
#  'Elvis Mitchell',
#  'A. H. Weiler',
#  'Roger Greenspun',
#  'Frank S. Nugent',
#  'Matt Zoller Seitz',
#  'Neil Genzlinger',
#  'Andy Webster',
#  'Jeannette Catsoulis',
#  'Nathan Lee',
#  'Kevin Cahillane',
#  'Laura Kern',
#  'Anna Kisselgoff',
#  'C. Hooper Trask',
#  'Ernest Marshall',
#  'Herbert L. Matthews',
#  'Herbert Mitgang',
# ...

# %%
df = pd.DataFrame(names)
df.columns = ['critic']
df.to_csv('critic.csv')

# %%
df = pd.read_csv('critic_fixed.csv', index_col = 0)

# %%
df
# Out:
#                  critic  gender
# 0           A. O. Scott    male
# 1        Manohla Dargis  female
# 2        Stephen Holden    male
# 3          Renata Adler  female
# 4         Mordaunt Hall    male
# 5       Thomas M. Pryor    male
# 6         Eugene Archer    male
# 7      Donal J. Henahan    male
# 8            Nora Sayre  female
# 9     D. J. R. Bruckner    male
# 10          Caryn James  female
# 11  Harold C. Schonberg    male
# 12          Tom Buckley    male
# 13     Stanley Kauffman    male
# 14       Andre Sennwald    male
# 15        Vincent Canby    male
# 16            Dave Kehr    male
# 17         Dana Stevens  female
# 18        B. R. Crisler    male
# 19        Hilton Kramer    male
# 20        Michael Stern    male
# 21      Bosley Crowther    male
# 22           Ned Martel    male
# 23     Theodore Strauss    male
# 24         Richard Eder    male
# 25         Janet Maslin  female
# 26      Howard Thompson    male
# 27          Anita Gates  female
# ...

# %%
df_gender = df.groupby(by = 'gender').count()

# %%
df_gender
# Out:
#         critic
# gender
# female      20
# male        62

# %%
response = requests.get('https://api.nytimes.com/svc/movies/v2/critics/Manohla%20Dargis.json?&api-key=AdAosfbrAgDSknKED1mN0EaAJPAbN5kB')
data2  = response.json()
data2
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'num_results': 1,
#  'results': [{'display_name': 'Manohla Dargis',
#    'sort_name': 'Manohla Dargis',
#    'status': 'full-time',
#    'bio': 'Manohla Dargis is the co-chief film critic for The Times, where she started in 2004. She has also written for The Los Angeles Times, where she was a chief film critic, and for the LA Weekly, where she was both a film critic and the film editor. She lives in Los Angeles.',
#    'seo_name': 'Manohla-Dargis',
#    'multimedia': None}]}

# %%
response = requests.get('https://api.nytimes.com/svc/movies/v2/reviews/all.json?&offset=40&api-key=AdAosfbrAgDSknKED1mN0EaAJPAbN5kB')
data2  = response.json()

n = 20

while data2['has_more'] == 'True':
    response = requests.get('https://api.nytimes.com/svc/movies/v2/reviews/all.json?&offset={n}&api-key=AdAosfbrAgDSknKED1mN0EaAJPAbN5kB')
data2
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'has_more': True,
#  'num_results': 20,
#  'results': [{'display_title': 'The Cat Rescuers',
#    'mpaa_rating': '',
#    'critics_pick': 0,
#    'byline': 'BILGE EBIRI',
#    'headline': '‘The Cat Rescuers’ Review: A Portrait of New York’s Street Cats and Their Loyal Humans',
#    'summary_short': 'New York is teeming with stray cats. Meet the people trying to do something about it.',
#    'publication_date': '2019-07-04',
#    'opening_date': '2019-07-05',
#    'date_updated': '2019-07-31 16:44:04',
#    'link': {'type': 'article',
#     'url': 'http://www.nytimes.com/2019/07/04/movies/the-cat-rescuers-review.html',
#     'suggested_link_text': 'Read the New York Times Review of The Cat Rescuers'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2019/07/05/arts/catrescuers1/catrescuers1-mediumThreeByTwo210.jpg',
# ...
